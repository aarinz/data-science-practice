# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = np.random.random(50)*100
y_data = np.random.random(50)*100

# %% [markdown]
# Scatter plot

# %%
plt.scatter(x_data, y_data)

# %%
print(x_data)
# Out:
# [ 6.74045075 58.54788669 79.3323709   2.26730428 75.52750035 38.31730244
#  95.14139952 19.19080632 58.4155363  52.89297118 72.89101077 64.4848887
#  23.49444037 60.56992115 48.231385   52.18344183 52.91292709 54.76547512
#  15.46901153 52.52431602 84.8657157  56.02965397 68.76171991 62.04694931
#  65.97440096 16.19396148 28.16008332 75.87088562 26.16073456 36.10801595
#  34.65268158 22.23806312 92.41938307 62.46160072  8.65303728 69.66747558
#  70.99625557 75.96045366 37.89052508 75.28306179 17.30527054 17.23807705
#  15.76312736  4.74039113 37.85090761 78.81703461 15.10332598 49.99939219
#  98.15200589 91.49180586]

# %%
print(y_data)
# Out:
# [68.4712035  80.64062194 93.10259017  6.64476771 62.34079255 92.47199857
#  62.41319944 84.76418029 79.90710649  8.90751898 34.9240325  71.49738388
#  76.58025989 46.11869252 98.44961305 87.7702353   8.20693424 33.3818516
#  46.53688361 92.86932168 66.87143845 27.53985621 55.8439377  31.49788313
#  42.67029748 53.79423874 56.76263595 41.05836451 85.07944177 59.77639559
#  70.91932815 40.88876169 52.14267749 91.82227697 68.95624791 67.64992689
#  59.98798475  6.53209836 30.77662644  8.63818174  9.21720979 20.52089601
#  66.65754758 45.54442889 34.18614176 70.0327897  78.86745777 90.65222675
#  95.10148465 34.05617828]

# %%
plt.scatter(x_data, y_data, c="red", s=150, marker="o", alpha=0.3)

# %% [markdown]
# Line plot

# %%
years = [2006 + x for x in range(16)]
weights = [20, 30, 68, 79, 98, 19, 49, 60, 67, 70, 79, 100, 45, 55, 78, 80]

# %%
print(len(years))
print(len(weights))
# Out:
# 16
# 16

# %%
plt.plot(years, weights)

# %%
plt.plot(years, weights, c="y", lw=5, linestyle="--")

# %% [markdown]
# Bar plot

# %%
x = ["C++", "C", "Python", "java", "C#"]
y = [30, 1, 70, 100, 50]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(years, weights)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.bar(x, y, color="g", align="edge", width=0.5)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Histogram plot

# %%
ages = np.random.normal(20, 1.5, 1000)

# %%
plt.hist(ages)
# Out:
# (array([  6.,  29.,  61., 130., 225., 240., 170.,  98.,  36.,   5.]),
#  array([15.15171561, 16.08671231, 17.02170901, 17.95670572, 18.89170242,
#         19.82669912, 20.76169582, 21.69669252, 22.63168923, 23.56668593,
#         24.50168263]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ages, bins=20)
# Out:
# (array([  1.,   5.,  13.,  16.,  20.,  41.,  70.,  60., 105., 120., 124.,
#         116.,  94.,  76.,  54.,  44.,  21.,  15.,   2.,   3.]),
#  array([15.15171561, 15.61921396, 16.08671231, 16.55421066, 17.02170901,
#         17.48920736, 17.95670572, 18.42420407, 18.89170242, 19.35920077,
#         19.82669912, 20.29419747, 20.76169582, 21.22919417, 21.69669252,
#         22.16419088, 22.63168923, 23.09918758, 23.56668593, 24.03418428,
#         24.50168263]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(ages, bins=20, cumulative=True)
# Out:
# (array([   1.,    6.,   19.,   35.,   55.,   96.,  166.,  226.,  331.,
#          451.,  575.,  691.,  785.,  861.,  915.,  959.,  980.,  995.,
#          997., 1000.]),
#  array([15.15171561, 15.61921396, 16.08671231, 16.55421066, 17.02170901,
#         17.48920736, 17.95670572, 18.42420407, 18.89170242, 19.35920077,
#         19.82669912, 20.29419747, 20.76169582, 21.22919417, 21.69669252,
#         22.16419088, 22.63168923, 23.09918758, 23.56668593, 24.03418428,
#         24.50168263]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Pie chart

# %%
langs = ["C++", "C", "Python", "java", "C#"]
votes = [30, 1, 70, 100, 50]

# %%
plt.pie(votes, labels=langs)
# Out:
# ([<matplotlib.patches.Wedge at 0x2bccfe78c10>,
# ...
#  [Text(1.0233611739630455, 0.4034004308686066, 'C++'),
#   Text(0.794666453981521, 0.7605953108693448, 'C'),
#   Text(-0.0893929491129072, 1.0963616650763093, 'Python'),
#   Text(-0.883400044681132, -0.6554421111413075, 'java'),
#   Text(0.8915345304432205, -0.6443339049183944, 'C#')])

# %%
explodes = [0,0.2, 0,0,0]

# %%
plt.pie(votes, labels=langs, explode=explodes, autopct = "%.2f%%", pctdistance=1.4, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2bccfd148d0>,
# ...
#  [Text(-0.40340043086860655, 1.0233611739630455, 'C++'),
#   Text(-0.8988853673910441, 0.9391512637963428, 'C'),
#   Text(-1.0963616650763093, -0.08939294911290713, 'Python'),
#   Text(0.6554421111413078, -0.8834000446811318, 'java'),
#   Text(0.6443339049183945, 0.8915345304432205, 'C#')],
#  [Text(-0.5134187301964083, 1.302459675952967, '11.95%'),
#   Text(-1.1063204521735925, 1.1558784785185756, '0.40%'),
#   Text(-1.3953693919153025, -0.11377284432551815, '27.89%'),
#   Text(0.8341990505434826, -1.1243273295941676, '39.84%'),
#   Text(0.820061333532502, 1.1346803114731896, '19.92%')])

# %% [markdown]
# Boxplots

# %%
heights = np.random.normal(172, 8, 300)

# %%
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bcd00753d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bcd00769d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bcd0074950>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bcd0077f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bcd00889d0>],
#  'means': []}

# %%
years = [2009, 2010, 2012, 2015, 2017, 2019, 2021, 2024]
income = [22, 33, 47, 61, 73, 87, 91, 98]

# %%
income_ticks = list(range(50,81,2))

# %%
plt.title("Income of peter", fontsize=30, fontname="Arial")
plt.xlabel("Year")
plt.ylabel("Income in USD")
plt.plot(years, income)

# %%
line_a = [100, 103, 105, 102, 100, 97, 99]
line_b = [92, 95, 107, 110, 99, 100, 96]
line_c = [110, 115, 100, 105, 92, 95, 98]

# %%
plt.plot(line_a, label="car1")
plt.plot(line_b, label="car2")
plt.plot(line_c, label="car3")

plt.legend()

# %%
langs = ["C++", "C", "Python", "java", "C#"]
votes = [30, 1, 70, 100, 50]

# %%
plt.pie(votes, labels=None)
plt.legend(labels=langs)

# %%
from matplotlib import style

# %%
style.use("dark_background")

# %%
plt.pie(votes, labels=None)
plt.legend(labels=langs)

# %%
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

# %%
plt.figure(1)
plt.scatter(x1, y1)

plt.figure(2)
plt.plot(x2, y2)

# %%
ax = plt.axes(projection="3d")

x = np.random.random(100)
y = np.random.random(100)
z = np.random.random(100)

ax.scatter(x, y, z)
ax.set_title("3D plot")
# Out:
# Text(0.5, 0.92, '3D plot')

# %%
ax = plt.axes(projection="3d")

x = np.arange(-5,5,0.1)
y = np.arange(-5,5,0.1)

x,y = np.meshgrid(x,y)

z = np.sin(x) * np.cos(y)

ax.plot_surface(x,y,z, cmap = "Spectral")
ax.set_title("3D plot")
ax.set_xlabel("test")
# Out:
# Text(0.5, 0, 'test')
