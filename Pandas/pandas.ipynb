# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "name": ['harry', 'rohan', 'skillf', 'shubh'],
    "marks": [92, 34, 24, 17],
    "city": ['rampur', 'kolkata', 'bareilly', 'antarctica']
}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
df.to_csv('friends.csv') #creates excel sheet of the table

# %%
df.to_csv('friends_index_false.csv', index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
df.tail(2)
# Out:
#      name  marks        city
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
df.describe() #counts numerical terms in the table
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
zach = pd.read_csv('zacht.csv') #to read a csv file existing in folder

# %%
zach
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train no.  speed        city
# 0             0             0           0       1234     50      rampur
# 1             1             1           1       5678    333     kolkata
# 2             2             2           2       9101    444    bareilly
# 3             3             3           3       1121    555  antarctica

# %%
zach['speed']
# Out:
# 0     50
# 1    333
# 2    444
# 3    555
# Name: speed, dtype: int64

# %%
zach['speed'][0]
# Out:
# 50

# %%
zach['speed'][0] = 50 #to change the value
# Out:
# C:\Users\Aarin Zacharia\AppData\Local\Temp\ipykernel_20256\3172984299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zach['speed'][0] = 50 #to change the value

# %%
zach
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train no.  speed        city
# 0             0             0           0       1234     50      rampur
# 1             1             1           1       5678    333     kolkata
# 2             2             2           2       9101    444    bareilly
# 3             3             3           3       1121    555  antarctica

# %%
zach.to_csv('zacht.csv')

# %%
zach.index = ['first', 'second', 'third', 'fourth']

# %%
zach
# Out:
#         Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train no.  speed        city
# first              0             0           0       1234     50      rampur
# second             1             1           1       5678    333     kolkata
# third              2             2           2       9101    444    bareilly
# fourth             3             3           3       1121    555  antarctica

# %% [markdown]
# ![image.png](attachment:850db69e-ff41-4ca5-a157-e715564aa909.png)
# ![image.png](attachment:667880b1-8b95-44e7-83b3-6678b9f675d3.png)

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.195899
# 1     0.535540
# 2     0.185662
# 3     0.814499
# 4     0.989742
# 5     0.979258
# 6     0.905810
# 7     0.097348
# 8     0.080246
# 9     0.795233
# 10    0.679043
# 11    0.892768
# 12    0.749970
# 13    0.722181
# 14    0.592673
# 15    0.770129
# 16    0.611730
# 17    0.549447
# 18    0.701049
# 19    0.362287
# 20    0.470239
# 21    0.956410
# 22    0.376583
# 23    0.377149
# 24    0.094007
# 25    0.338249
# 26    0.909552
# 27    0.731039
# 28    0.513081
# 29    0.510798
# 30    0.966324
# 31    0.229208
# 32    0.831302
# 33    0.496817
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.761528  0.592763  0.044240  0.868868  0.690334
# 1  0.773485  0.301828  0.030997  0.478009  0.663424
# 2  0.172391  0.209025  0.373971  0.039946  0.975630
# 3  0.301654  0.553636  0.401989  0.054462  0.630738
# 4  0.886983  0.512883  0.055052  0.238359  0.084092

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.761528  0.592763  0.044240  0.868868  0.690334
# 1    0.773485  0.301828  0.030997  0.478009  0.663424
# 2    0.172391  0.209025  0.373971  0.039946  0.975630
# 3    0.301654  0.553636  0.401989  0.054462  0.630738
# 4    0.886983  0.512883  0.055052  0.238359  0.084092
# ..        ...       ...       ...       ...       ...
# 329  0.059806  0.654033  0.017508  0.183348  0.769578
# 330  0.554638  0.095853  0.563696  0.866362  0.550468
# 331  0.803947  0.101647  0.423426  0.301071  0.678591
# 332  0.456841  0.535734  0.444768  0.095221  0.669290
# 333  0.487838  0.338316  0.966616  0.649453  0.162590
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,0] = 983

# %%
newdf.head(3)
# Out:
#           q         w         e         r         t      0
# 0       928  0.592763  0.044240  0.868868  0.690334  983.0
# 1  0.773485  0.301828  0.030997  0.478009  0.663424    NaN
# 2  0.172391  0.209025  0.373971  0.039946  0.975630    NaN

# %%
newdf.loc[0,"q"] = 238293

# %%
newdf.head(3)
# Out:
#           q         w         e         r         t      0
# 0    238293  0.592763  0.044240  0.868868  0.690334  983.0
# 1  0.773485  0.301828  0.030997  0.478009  0.663424    NaN
# 2  0.172391  0.209025  0.373971  0.039946  0.975630    NaN

# %%
newdf.drop(0, axis=1)
# Out:
#             q         w         e         r         t
# 0      238293  0.592763  0.044240  0.868868  0.690334
# 1    0.773485  0.301828  0.030997  0.478009  0.663424
# 2    0.172391  0.209025  0.373971  0.039946  0.975630
# 3    0.301654  0.553636  0.401989  0.054462  0.630738
# 4    0.886983  0.512883  0.055052  0.238359  0.084092
# ..        ...       ...       ...       ...       ...
# 329  0.059806  0.654033  0.017508  0.183348  0.769578
# 330  0.554638  0.095853  0.563696  0.866362  0.550468
# 331  0.803947  0.101647  0.423426  0.301071  0.678591
# 332  0.456841  0.535734  0.444768  0.095221  0.669290
# 333  0.487838  0.338316  0.966616  0.649453  0.162590
#
# [334 rows x 5 columns]

# %%
newdf.loc[[1,2], ['w','e']]
# Out:
#           w         e
# 1  0.301828  0.030997
# 2  0.209025  0.373971

# %%
newdf.loc[(newdf['q']<0.3)]
# Out:
#             q         w         e         r         t   0
# 2    0.172391  0.209025  0.373971  0.039946  0.975630 NaN
# 5    0.052602  0.194647  0.854901  0.514922  0.986941 NaN
# 8    0.243605  0.321226  0.317984  0.229121  0.946935 NaN
# 12   0.182103  0.785475  0.461596  0.272727  0.423264 NaN
# 14   0.060826  0.561140  0.264170  0.965262  0.445742 NaN
# ..        ...       ...       ...       ...       ...  ..
# 315  0.270893  0.000801  0.795564  0.417228  0.636361 NaN
# 317  0.217906  0.558546  0.789364  0.354828  0.390029 NaN
# 320  0.284166  0.417075  0.847985  0.874143  0.966224 NaN
# 325  0.153782  0.649586  0.407373  0.632497  0.940320 NaN
# 329  0.059806  0.654033  0.017508  0.183348  0.769578 NaN
#
# [89 rows x 6 columns]

# %%
newdf.loc[(newdf['q']<0.3) & (newdf['w']>0.1)]
# Out:
#             q         w         e         r         t   0
# 2    0.172391  0.209025  0.373971  0.039946  0.975630 NaN
# 5    0.052602  0.194647  0.854901  0.514922  0.986941 NaN
# 8    0.243605  0.321226  0.317984  0.229121  0.946935 NaN
# 12   0.182103  0.785475  0.461596  0.272727  0.423264 NaN
# 14   0.060826  0.561140  0.264170  0.965262  0.445742 NaN
# ..        ...       ...       ...       ...       ...  ..
# 314  0.123466  0.903675  0.943220  0.505824  0.122689 NaN
# 317  0.217906  0.558546  0.789364  0.354828  0.390029 NaN
# 320  0.284166  0.417075  0.847985  0.874143  0.966224 NaN
# 325  0.153782  0.649586  0.407373  0.632497  0.940320 NaN
# 329  0.059806  0.654033  0.017508  0.183348  0.769578 NaN
#
# [76 rows x 6 columns]

# %%
newdf.iloc[0,4]
# Out:
# 0.6903341583075138

# %%
newdf.head(2)
# Out:
#           q         w         e         r         t      0
# 0    238293  0.592763  0.044240  0.868868  0.690334  983.0
# 1  0.773485  0.301828  0.030997  0.478009  0.663424    NaN

# %% [markdown]
# .loc is label-based, allowing access to data using row and column labels.
#
# .iloc is integer-based, allowing access to data using row and column index positions.

# %%
newdf.iloc[[0,4], [1,2]]
# Out:
#           w         e
# 0  0.592763  0.044240
# 4  0.512883  0.055052

# %%
newdf.head(3)
# Out:
#           q         w         e         r         t      0
# 0    238293  0.592763  0.044240  0.868868  0.690334  983.0
# 1  0.773485  0.301828  0.030997  0.478009  0.663424    NaN
# 2  0.172391  0.209025  0.373971  0.039946  0.975630    NaN

# %%
newdf.drop([0], axis=1)
# Out:
#             q         w         e         r         t
# 0      238293  0.592763  0.044240  0.868868  0.690334
# 1    0.773485  0.301828  0.030997  0.478009  0.663424
# 2    0.172391  0.209025  0.373971  0.039946  0.975630
# 3    0.301654  0.553636  0.401989  0.054462  0.630738
# 4    0.886983  0.512883  0.055052  0.238359  0.084092
# ..        ...       ...       ...       ...       ...
# 329  0.059806  0.654033  0.017508  0.183348  0.769578
# 330  0.554638  0.095853  0.563696  0.866362  0.550468
# 331  0.803947  0.101647  0.423426  0.301071  0.678591
# 332  0.456841  0.535734  0.444768  0.095221  0.669290
# 333  0.487838  0.338316  0.966616  0.649453  0.162590
#
# [334 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#           q         w         e         r         t      0
# 0    238293  0.592763  0.044240  0.868868  0.690334  983.0
# 1  0.773485  0.301828  0.030997  0.478009  0.663424    NaN

# %%
newdf.drop([0], axis=1, inplace=True) #this makes the change permanent

# %%
newdf
# Out:
#             q         w         e         r         t
# 0      238293  0.592763  0.044240  0.868868  0.690334
# 1    0.773485  0.301828  0.030997  0.478009  0.663424
# 2    0.172391  0.209025  0.373971  0.039946  0.975630
# 3    0.301654  0.553636  0.401989  0.054462  0.630738
# 4    0.886983  0.512883  0.055052  0.238359  0.084092
# ..        ...       ...       ...       ...       ...
# 329  0.059806  0.654033  0.017508  0.183348  0.769578
# 330  0.554638  0.095853  0.563696  0.866362  0.550468
# 331  0.803947  0.101647  0.423426  0.301071  0.678591
# 332  0.456841  0.535734  0.444768  0.095221  0.669290
# 333  0.487838  0.338316  0.966616  0.649453  0.162590
#
# [334 rows x 5 columns]

# %%
df = pd.DataFrame({
    "name": ['Hulk', 'Batman', 'Catwoman'],
    "toy": [np.nan, 'Batmoble', 'Whip'],
    "born": [pd.NaT, "1940-04-25", pd.NaT]
})

# %%
df.head
# Out:
# <bound method NDFrame.head of        name       toy        born
# 0      Hulk       NaN         NaT
# 1    Batman  Batmoble  1940-04-25
# 2  Catwoman      Whip         NaT>

# %%
df
# Out:
#        name       toy        born
# 0      Hulk       NaN         NaT
# 1    Batman  Batmoble  1940-04-25
# 2  Catwoman      Whip         NaT

# %%
df.dropna()
# Out:
#      name       toy        born
# 1  Batman  Batmoble  1940-04-25

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
df['name'].value_counts(dropna=False)
# Out:
# name
# Hulk        1
# Batman      1
# Catwoman    1
# Name: count, dtype: int64
